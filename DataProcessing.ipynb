# %%
import pandas as pd
from sqlalchemy import create_engine
con = create_engine("mysql+pymysql://root:bhargav#7769@localhost:3306/INVENTORY_DB")

# %%
pd.read_sql_query(" select * from purchase_prices  limit 5" , con)
# Out:
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.28          8320  SHAW ROSS INT L IMP LTD
# 1          28.67          1128  BROWN-FORMAN CORP
# 2          30.46          1128  BROWN-FORMAN CORP
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4          10.94          7245  PROXIMO SPIRITS INC.

# %%
(pd.read_sql_query(" select count(*) as purchases from  purchases limit 5" , con),
pd.read_sql_query(" select count(*) as sales from  sales limit 5" , con),
pd.read_sql_query(" select count(*) as  purchase_prices from  purchase_prices limit 5" , con),
pd.read_sql_query(" select count(*) as  vendor_invoice  from  vendor_invoice limit 5" , con))
# Out:
# (   purchases
#  0    2372474,
#        sales
#  0  12825363,
#     purchase_prices
#  0            12261,
#     vendor_invoice
#  0            5543)

# %%
query = "SHOW TABLES"
tables = pd.read_sql(query, con)

# Show tables
print(tables)
# Out:
#   Tables_in_inventory_db
# 0        begin_inventory
# 1          end_inventory
# 2        purchase_prices
# 3              purchases
# 4                  sales
# 5         vendor_invoice

# %%
tables.columns = ['name']  # Rename column

# Loop through tables and print record counts
for table in tables['name']:
    print('-'*50, f'{table}', '-'*50)
    count = pd.read_sql(f"SELECT COUNT(*) AS count FROM `{table}`", con)['count'].values[0]
    print('Count of records:', count)
    print()
    display(pd.read_sql_query(f"select * from {table} limit 5" , con))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of records: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
# ...

# %%
purchaces = pd.read_sql_query(' select * from purchases  ',con)

# %%
sales = pd.read_sql_query(' select * from sales where brand = 58 limit 3',con)

# %%
purchaces.groupby(["Brand" , "PurchasePrice"])[['Quantity' , 'Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 58    9.28               3550  32944.00
# 60    7.40               1633  12084.20
# 61    10.60               312   3307.20
# 62    28.67              3200  91744.00
# 63    30.46              2855  86963.30
# ...                       ...       ...
# 90089 77.92                32   2493.44
# 90090 448.27                6   2689.62
# 90604 78.42               118   9253.56
# 90609 17.00               321   5457.00
# 90631 12.74              1938  24690.12
#
# [10664 rows x 2 columns]

# %% [markdown]
# As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:
#
# purchase transactions made by vendors
#
# sales transaction data
#
# freight costs for each vendor
#
# actual product prices from vendors

# %% [markdown]
# freight cost for each vendor

# %%
pd.read_sql_query('select * from vendor_invoice limit 1',con)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6   214.26     3.47     None

# %%
pd.read_sql_query(""" select 
                  VendorNumber ,
                  VendorName ,
                  sum(freight) as FrieghtCost 
                  from  
                  vendor_invoice 
                group by 
                  vendornumber , vendorname""" ,
                 con)
# Out:
#      VendorNumber                   VendorName  FrieghtCost
# 0             105  ALTAMAR BRANDS LLC                 62.39
# 1            4466  AMERICAN VINTAGE BEVERAGE         793.91
# 2             388  ATLANTIC IMPORTING COMPANY        211.74
# 3             480  BACARDI USA INC                 89286.27
# 4             516  BANFI PRODUCTS CORP              8510.41
# ..            ...                          ...          ...
# 124          4901  LAUREATE IMPORTS CO                 0.72
# 125         90059  BLACK COVE BEVERAGES               74.84
# 126          5083  LOYAL DOG WINERY                   10.68
# 127          1587  VINEYARD BRANDS LLC                54.23
# 128            54  AAPER ALCOHOL & CHEMICAL CO         0.48
#
# [129 rows x 3 columns]

# %%
(pd.read_sql_query( ' select * from purchases limit 0' , con),
pd.read_sql_query( ' select * from purchase_prices limit 0' , con))
# Out:
# (Empty DataFrame
#  Columns: [InventoryId, Store, Brand, Description, Size, VendorNumber, VendorName, PONumber, PODate, ReceivingDate, InvoiceDate, PayDate, PurchasePrice, Quantity, Dollars, Classification]
#  Index: [],
#  Empty DataFrame
#  Columns: [Brand, Description, Price, Size, Volume, Classification, PurchasePrice, VendorNumber, VendorName]
#  Index: [])

# %%
pd.read_sql_query("""
            select 
                  p.VendorNumber,
                  p.VendorName,
                  p.Brand,
                  p.PurchasePrice,
                  pp.volume,
                  pp.price as ActualPrice,
                  sum(p.Quantity) As TotalPurchaseQuantity,
                  sum(p.dollars) As TotalPurchaseDollars
            from  purchases p 
            join
                  purchase_prices pp
                  on 
                  p.brand = pp.brand
            where p.purchasePrice > 0
            group by
                  p.VendorNumber,
                  p.VendorName ,
                  p.Brand , 
                  p.PurchasePrice,
                  pp.Volume,
                  pp.Price
                  order by TotalPurchaseDollars""" , con)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
pd.read_sql_query(" select * from sales limit 0" ,con)
# Out:
# Empty DataFrame
# Columns: [InventoryId, Store, Brand, Description, Size, SalesQuantity, SalesDollars, SalesPrice, SalesDate, Volume, Classification, ExciseTax, VendorNo, VendorName]
# Index: []

# %%
pd.read_sql_query(""" 
              Select
                  VendorNo,
                  Brand,
                  sum(salesdollars) as TotalSalesDollars,
                  sum(salesprice) as TotalSalesPrice,
                  sum(salesQuantity) as TotalSalesQuantity
              from sales
              group by 
                  VendorNo,Brand
""", con)
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity
# 0         12546   1004           15708.97         11365.46               703.0
# 1         12546   1005           32120.82         19349.47               918.0
# 2          2000  10058          293349.46        113447.03             21018.0
# 3         12546   1006            1308.72           323.19               328.0
# 4         10754  10062           18518.71         11417.50              2029.0
# ...         ...    ...                ...              ...                 ...
# 11267      4425  27700              88.99            88.99                 1.0
# 11268      4425  27851              37.98            37.98                 2.0
# 11269      2000  27969              36.99            36.99                 1.0
# 11270     12331    263              35.98            35.98                 2.0
# 11271      3924   9123               1.98             0.99                 2.0
#
# ...

# %% [markdown]
# creating final table

# %%
pd.read_sql_query(""" 
WITH FreightSummary AS (
    SELECT 
        VendorNumber,
        VendorName,
        SUM(freight) AS FreightCost
    FROM vendor_invoice 
    GROUP BY VendorNumber, VendorName
),
PurchaseSummary AS (
    SELECT 
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.PurchasePrice,
        pp.volume,
        pp.price AS ActualPrice,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.dollars) AS TotalPurchaseDollars
    FROM purchases p 
    JOIN purchase_prices pp
        ON p.brand = pp.brand
    WHERE p.PurchasePrice > 0
    GROUP BY
        p.VendorNumber,
        p.VendorName,
        p.Brand, 
        p.PurchasePrice,
        pp.Volume,
        pp.Price
),
SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(salesdollars) AS TotalSalesDollars,
        SUM(salesprice) AS TotalSalesPrice,
        SUM(salesQuantity) AS TotalSalesQuantity
    FROM sales
    GROUP BY VendorNo, Brand
)
SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.Brand = ss.Brand AND ps.VendorNumber = ss.VendorNo
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber                            
""", con)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
final_Table = pd.read_sql_query(""" 
WITH FreightSummary AS (
    SELECT 
        VendorNumber,
        VendorName,
        SUM(freight) AS FreightCost 
    FROM vendor_invoice 
    GROUP BY VendorNumber, VendorName
),
PurchaseSummary AS (
    SELECT 
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.PurchasePrice,
        pp.volume,
        pp.price AS ActualPrice,                       
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.dollars) AS TotalPurchaseDollars
    FROM purchases p 
    JOIN purchase_prices pp ON p.brand = pp.brand
    WHERE p.PurchasePrice > 0
    GROUP BY
        p.VendorNumber,
        p.VendorName,
        p.Brand, 
        p.PurchasePrice,
        pp.Volume,
        pp.Price
),
SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(salesdollars) AS TotalSalesDollars,
        SUM(salesprice) AS TotalSalesPrice,
        SUM(salesQuantity) AS TotalSalesQuantity
    FROM sales 
    GROUP BY VendorNo, Brand
    HAVING SUM(salesdollars) > 0
)
SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,                            
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,                                                       
    ss.TotalSalesDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesPrice,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.Brand = ss.Brand AND ps.VendorNumber = ss.VendorNo
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber                            
""", con)

final_Table  # <- No print()
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
final_Table.describe()
# Out:
#         VendorNumber         Brand  PurchasePrice   ActualPrice  \
# count   12489.000000  12489.000000   12489.000000  12489.000000
# mean     9672.998799  18847.561134      24.892217     36.601191
# std     17519.491679  12524.982470     103.582221    141.237886
# min         2.000000     58.000000       0.360000      0.490000
# 25%      3960.000000   6919.000000       7.140000     10.990000
# 50%      4425.000000  19693.000000      10.800000     16.990000
# 75%      9552.000000  25827.000000      20.430000     29.990000
# max    201359.000000  90631.000000    5681.810000   7499.990000
#
#        TotalPurchaseQuantity  TotalPurchaseDollars  TotalSalesDollars  \
# count           12489.000000          1.248900e+04       1.228000e+04
# mean             2946.748178          2.840181e+04       4.073060e+04
# std             10618.653774          1.203342e+05       1.648646e+05
# min                 1.000000          7.100000e-01       1.980000e+00
# ...

# %%
final_Table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12489 entries, 0 to 12488
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorNumber           12489 non-null  int64
#  1   VendorName             12489 non-null  object
#  2   Brand                  12489 non-null  int64
#  3   PurchasePrice          12489 non-null  float64
#  4   ActualPrice            12489 non-null  float64
#  5   Volume                 12489 non-null  float64
#  6   TotalPurchaseQuantity  12489 non-null  float64
#  7   TotalPurchaseDollars   12489 non-null  float64
#  8   TotalSalesDollars      12489 non-null  float64
#  9   TotalSalesQuantity     12489 non-null  float64
#  10  TotalSalesPrice        12489 non-null  float64
#  11  FreightCost            12489 non-null  float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 1.1+ MB

# %%
final_Table.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# PurchasePrice            0
# ActualPrice              0
# Volume                   0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalSalesDollars        0
# TotalSalesQuantity       0
# TotalSalesPrice          0
# FreightCost              0
# dtype: int64

# %%
final_Table['Volume'] = final_Table['Volume'].astype('float')

# %%
final_Table['VendorName'] = final_Table['VendorName'].astype('object')

# %%
final_Table.fillna(0 , inplace= True)

# %% [markdown]
# adding required columns

# %%
#Adding Gross Profit
final_Table['GrossProfit'] = final_Table['TotalSalesDollars'] - final_Table['TotalPurchaseDollars']

# %%
final_Table
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
#Adding Profit Margin

final_Table['ProfitMargin'] = (final_Table['GrossProfit'] / final_Table['TotalSalesDollars']) * 100

final_Table
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
#Adding Stock turnover

final_Table['StockTurnover'] = final_Table['TotalSalesQuantity'] / final_Table['TotalPurchaseQuantity']

final_Table
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
#Adding SalesToPurchaseRatio

final_Table['SalesToPurchaseRatio'] = final_Table['TotalSalesDollars'] / final_Table['TotalPurchaseDollars']

final_Table
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12488          9165  ULTRA BEVERAGE COMPANY LLP    1073          25.73
#
#        ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
import numpy as np
final_Table.replace([np.inf, -np.inf], np.nan, inplace=True)
final_Table.dropna(inplace=True)
final_Table
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0               105  ALTAMAR BRANDS LLC            8412          35.71
# 1              4466  AMERICAN VINTAGE BEVERAGE     5255           9.35
# 2              4466  AMERICAN VINTAGE BEVERAGE     5215           9.41
# 3               480  BACARDI USA INC               3348          22.38
# 4               480  BACARDI USA INC               8358          14.49
# ...             ...                          ...    ...            ...
# 12479          4425        MARTIGNETTI COMPANIES  27886          10.06
# 12484          7153  PINE STATE TRADING CO        26508           6.81
# 12485          8004  SAZERAC CO INC                2936          53.02
# 12486          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
# 12487          2000  SOUTHERN WINE & SPIRITS NE   26266          11.56
#
#        ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# ...

# %%
final_Table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12280 entries, 0 to 12487
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorNumber           12280 non-null  int64
#  1   VendorName             12280 non-null  object
#  2   Brand                  12280 non-null  int64
#  3   PurchasePrice          12280 non-null  float64
#  4   ActualPrice            12280 non-null  float64
#  5   Volume                 12280 non-null  float64
#  6   TotalPurchaseQuantity  12280 non-null  float64
#  7   TotalPurchaseDollars   12280 non-null  float64
#  8   TotalSalesDollars      12280 non-null  float64
#  9   TotalSalesQuantity     12280 non-null  float64
#  10  TotalSalesPrice        12280 non-null  float64
#  11  FreightCost            12280 non-null  float64
#  12  GrossProfit            12280 non-null  float64
#  13  ProfitMargin           12280 non-null  float64
# ...

# %%
engine = create_engine("mysql+pymysql://root:bhargav#7769@localhost:3306/inventory_db")
final_Table.to_sql(name='sales_summary', con=engine, index=False, if_exists='replace')
# Out:
# 12280

# %%
pd.read_sql_query(' select * from sales_summary limit 0' ,engine)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, PurchasePrice, ActualPrice, Volume, TotalPurchaseQuantity, TotalPurchaseDollars, TotalSalesDollars, TotalSalesQuantity, TotalSalesPrice, FreightCost, GrossProfit, ProfitMargin, StockTurnover, SalesToPurchaseRatio]
# Index: []
